# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import sklearn.feature_selection
import torch

import xgboost as xgb

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('train.csv')

# %%
how_many_nas = []

for column in data.columns:
    how_many_nas.append(data[data[column].isna()].shape[0])

plt.plot(how_many_nas)
plt.xticks(np.arange(0, len(data.columns),1),data.columns, rotation=65)
plt.yscale('log')

# %%
data = data[data['wap'].notna()]

# %%
how_many_nas = []

for column in data.columns:
    how_many_nas.append(data[data[column].isna()].shape[0])

plt.plot(how_many_nas)
plt.xticks(np.arange(0, len(data.columns),1),data.columns, rotation=65)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
data['imbalance'] = data['imbalance_size']*data['imbalance_buy_sell_flag']

# %%
train, val = data[data['date_id']<400], data[data['date_id']>=400]
train = train.drop(['row_id'], axis=1)


val = val.drop(['row_id'], axis=1)

quantitative_features = ['seconds_in_bucket', 
                         'imbalance', 
                         'reference_price', 
                         'matched_size', 
                         'bid_price', 
                         'bid_size', 
                         'ask_price', 
                         'ask_size', 
                         'wap']

# %%
autocorr_over_dates = {}
cint_over_dates = {}

for group_name, df_group in train.groupby(['date_id', 'stock_id']):
    autocorr_over_dates[group_name], cint_over_dates[group_name] = pacf(df_group['wap'], alpha=0.05)

# %%
stock_return_array = np.zeros((train['stock_id'].nunique(), train['date_id'].nunique(), train['seconds_in_bucket'].nunique()))
index_return_array = np.zeros((train['stock_id'].nunique(), train['date_id'].nunique(), train['seconds_in_bucket'].nunique()))



for group_name, df_group in train.groupby(['stock_id', 'date_id']):
    df_group['stock_return'] = (df_group['wap'].shift(-6)/df_group['wap'] - 1)*10000
    df_group['index_return'] = (df_group['stock_return'] - df_group['target'])
    stock_return_array[group_name[0], group_name[1]] = df_group['stock_return'].values
    index_return_array[group_name[0], group_name[1]] = df_group['index_return'].values

# %%
index_returns = np.asarray([np.mean(index_return_array[:,i,0], axis=0) for i in range(train['date_id'].nunique())])

# %%
stock_returns = stock_return_array[:,:,0]

# %%
lr = LinearRegression()
lr.fit(np.transpose(stock_returns), index_returns)
# Out:
# LinearRegression()

# %%
index_weights = lr.coef_
index_weights_df = pd.DataFrame.from_dict({'stock_id': [i for i in range(200)], 'weight': [index_weights[i] for i in range(200)]})
train_with_weights = pd.merge(train, index_weights_df, on='stock_id')
val_with_weights   = pd.merge(val,   index_weights_df, on='stock_id')

# %%
autocorr = np.zeros((len(autocorr_over_dates.keys()),18))

lower_range = np.zeros((len(autocorr_over_dates.keys()),18))
upper_range = np.zeros((len(autocorr_over_dates.keys()),18))

counter = 0
for index, key in enumerate(autocorr_over_dates.keys()):
    
    if not sum(abs(autocorr_over_dates[key])>1)>=1 and autocorr_over_dates[key].shape[0]==18: 
        counter+=1
        autocorr[index,:] = autocorr_over_dates[key]
        lower_range[index,:] = cint_over_dates[key][:,0]
        upper_range[index,:] = cint_over_dates[key][:,1]
    else:
        autocorr[index,:] = np.asarray(18*[np.nan])
        lower_range[index,:] = np.asarray(18*[np.nan])
        upper_range[index,:] = np.asarray(18*[np.nan])

# %%
plt.plot(np.arange(0,180,10), np.nanmean(autocorr, axis=0) )
plt.fill_between(np.arange(0,180,10), 
                 np.nanmean(lower_range, axis=0) , 
                 np.nanmean(upper_range, axis=0) ,
                 alpha=0.1)


plt.ylabel('Partial Autocorrelation')
plt.xlabel('Lag')
#plt.ylim(-1,1)
# Out:
# Text(0.5, 0, 'Lag')

# %%
train_with_weights
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0      3180602.69
# 1               0        0                 10      1299772.70
# 2               0        0                 20      1299772.70
# 3               0        0                 30      1299772.70
# 4               0        0                 40      1218204.43
# ...           ...      ...                ...             ...
# 4346810       102      399                500            0.00
# 4346811       102      399                510            0.00
# 4346812       102      399                520            0.00
# 4346813       102      399                530            0.00
# 4346814       102      399                540            0.00
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                              1         0.999812   13380276.64        NaN
# 1                              1         1.000026   15261106.63        NaN
# 2                              1         0.999919   15261106.63        NaN
# 3                              1         1.000133   15261106.63        NaN
# 4                              1         1.000455   15342674.90        NaN
# ...                          ...              ...           ...        ...
# 4346810                        0         1.001493   28997408.62   1.001493
# 4346811                        0         1.002061   28891834.24   1.002061
# 4346812                        0         1.002061   28891834.24   1.002061
# 4346813                        0         1.001891   28891834.24   1.001891
# 4346814                        0         1.001834   28891834.24   1.001834
#
#          near_price  bid_price  ...  shifted by 4 ask_size  \
# 0               NaN   0.999812  ...                    NaN
# 1               NaN   0.999812  ...                    NaN
# 2               NaN   0.999812  ...                    NaN
# 3               NaN   1.000026  ...                    NaN
# 4               NaN   1.000241  ...                8493.03
# ...             ...        ...  ...                    ...
# 4346810    1.001493   1.001209  ...               53385.57
# 4346811    1.002061   1.001891  ...              117518.73
# 4346812    1.002061   1.001834  ...              106242.57
# 4346813    1.001891   1.001664  ...               35420.22
# 4346814    1.001834   1.001550  ...               58505.04
#
#          shifted by 5 ask_size  shifted by 6 ask_size  shifted by 1 wap  \
# 0                          NaN                    NaN               NaN
# 1                          NaN                    NaN          1.000000
# 2                          NaN                    NaN          0.999892
# 3                          NaN                    NaN          0.999842
# 4                          NaN                    NaN          1.000085
# ...                        ...                    ...               ...
# 4346810               69575.30               34171.16          1.001425
# 4346811               53385.57               69575.30          1.001274
# 4346812              117518.73               53385.57          1.002027
# 4346813              106242.57              117518.73          1.002022
# 4346814               35420.22              106242.57          1.001855
#
#          shifted by 2 wap  shifted by 3 wap  shifted by 4 wap  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                1.000000               NaN               NaN
# 3                0.999892          1.000000               NaN
# 4                0.999842          0.999892          1.000000
# ...                   ...               ...               ...
# 4346810          1.001041          1.001012          1.001152
# 4346811          1.001425          1.001041          1.001012
# 4346812          1.001274          1.001425          1.001041
# 4346813          1.002027          1.001274          1.001425
# 4346814          1.002022          1.002027          1.001274
#
#          shifted by 5 wap  shifted by 6 wap  new_target
# 0                     NaN               NaN    1.000517
# 1                     NaN               NaN    1.000421
# 2                     NaN               NaN    1.000148
# 3                     NaN               NaN    1.000426
# 4                     NaN               NaN    1.000261
# ...                   ...               ...         ...
# 4346810          1.000789          1.000859         NaN
# 4346811          1.001152          1.000789         NaN
# 4346812          1.001012          1.001152         NaN
# 4346813          1.001041          1.001012         NaN
# 4346814          1.001425          1.001041         NaN
#
# [4346815 rows x 73 columns]

# %%
for feature in quantitative_features:
    for i in range(1, 7):
        train_with_weights['shifted by '+str(i) + " " + feature] = train_with_weights.groupby(['date_id', 'stock_id'])[feature].shift(i)
        val_with_weights['shifted by '+str(i) + " "+feature] = val_with_weights.groupby(['date_id', 'stock_id'])[feature].shift(i)

# %%
test = train_with_weights.fillna(method ='ffill')
# Out:
# /var/folders/t5/hglcpfcd3px36gr5wgd_4mtm0000gn/T/ipykernel_51091/579721010.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test = train_with_weights.fillna(method ='ffill')

# %%
train_with_weights.bfill()
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0      3180602.69
# 1               0        0                 10      1299772.70
# 2               0        0                 20      1299772.70
# 3               0        0                 30      1299772.70
# 4               0        0                 40      1218204.43
# ...           ...      ...                ...             ...
# 4346810       102      399                500            0.00
# 4346811       102      399                510            0.00
# 4346812       102      399                520            0.00
# 4346813       102      399                530            0.00
# 4346814       102      399                540            0.00
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                              1         0.999812   13380276.64   1.000241
# 1                              1         1.000026   15261106.63   1.000241
# 2                              1         0.999919   15261106.63   1.000241
# 3                              1         1.000133   15261106.63   1.000241
# 4                              1         1.000455   15342674.90   1.000241
# ...                          ...              ...           ...        ...
# 4346810                        0         1.001493   28997408.62   1.001493
# 4346811                        0         1.002061   28891834.24   1.002061
# 4346812                        0         1.002061   28891834.24   1.002061
# 4346813                        0         1.001891   28891834.24   1.001891
# 4346814                        0         1.001834   28891834.24   1.001834
#
#          near_price  bid_price  ...  shifted by 4 ask_size  \
# 0          1.000241   0.999812  ...                8493.03
# 1          1.000241   0.999812  ...                8493.03
# 2          1.000241   0.999812  ...                8493.03
# 3          1.000241   1.000026  ...                8493.03
# 4          1.000241   1.000241  ...                8493.03
# ...             ...        ...  ...                    ...
# 4346810    1.001493   1.001209  ...               53385.57
# 4346811    1.002061   1.001891  ...              117518.73
# 4346812    1.002061   1.001834  ...              106242.57
# 4346813    1.001891   1.001664  ...               35420.22
# 4346814    1.001834   1.001550  ...               58505.04
#
#          shifted by 5 ask_size  shifted by 6 ask_size  shifted by 1 wap  \
# 0                      8493.03                8493.03          1.000000
# 1                      8493.03                8493.03          1.000000
# 2                      8493.03                8493.03          0.999892
# 3                      8493.03                8493.03          0.999842
# 4                      8493.03                8493.03          1.000085
# ...                        ...                    ...               ...
# 4346810               69575.30               34171.16          1.001425
# 4346811               53385.57               69575.30          1.001274
# 4346812              117518.73               53385.57          1.002027
# 4346813              106242.57              117518.73          1.002022
# 4346814               35420.22              106242.57          1.001855
#
#          shifted by 2 wap  shifted by 3 wap  shifted by 4 wap  \
# 0                1.000000          1.000000          1.000000
# 1                1.000000          1.000000          1.000000
# 2                1.000000          1.000000          1.000000
# 3                0.999892          1.000000          1.000000
# 4                0.999842          0.999892          1.000000
# ...                   ...               ...               ...
# 4346810          1.001041          1.001012          1.001152
# 4346811          1.001425          1.001041          1.001012
# 4346812          1.001274          1.001425          1.001041
# 4346813          1.002027          1.001274          1.001425
# 4346814          1.002022          1.002027          1.001274
#
#          shifted by 5 wap  shifted by 6 wap  new_target
# 0                1.000000          1.000000    1.000517
# 1                1.000000          1.000000    1.000421
# 2                1.000000          1.000000    1.000148
# 3                1.000000          1.000000    1.000426
# 4                1.000000          1.000000    1.000261
# ...                   ...               ...         ...
# 4346810          1.000789          1.000859         NaN
# 4346811          1.001152          1.000789         NaN
# 4346812          1.001012          1.001152         NaN
# 4346813          1.001041          1.001012         NaN
# 4346814          1.001425          1.001041         NaN
#
# [4346815 rows x 73 columns]

# %%
train_with_weights['new_target'] = train_with_weights.groupby(['date_id', 'stock_id'])['wap'].shift(-6)
val_with_weights['new_target'] = val_with_weights.groupby(['date_id', 'stock_id'])['wap'].shift(-6)

# %%
training_features = quantitative_features.copy()
training_features.extend(['shifted by {} '.format(i)+feature for feature in quantitative_features for i in range(1,7)])

# %%
training_features_and_target = training_features + ['target']
training_features_and_new_target = training_features + ['new_target']
plt.imshow(train_with_weights[quantitative_features].corr())
plt.xticks(np.arange(0,len(quantitative_features)), quantitative_features, rotation=90)
plt.yticks(np.arange(0,len(quantitative_features)), quantitative_features, rotation=0)
plt.colorbar()
plt.show()

# %%
plt.imshow(train_with_weights[training_features_and_target].corr())

# %%
one_hot_stock_id_train = pd.get_dummies(train_with_weights['stock_id'], dtype=float)
one_hot_stock_id_val = pd.get_dummies(val_with_weights['stock_id'], dtype=float)

train_one_hot_stocks = train_with_weights.join(one_hot_stock_id_train)
val_one_hot_stocks = val_with_weights.join(one_hot_stock_id_val)

training_features_and_one_hot_and_new_target = training_features_and_new_target.copy()
training_features_and_one_hot_and_new_target.extend([i for i in range(200)])

training_features_and_one_hot = training_features.copy()
training_features_and_one_hot.extend([i for i in range(200)])

# %%
training_data_for_regressor = train_with_weights[training_features_and_target].dropna()

x_train = training_data_for_regressor[training_features]
y_train = training_data_for_regressor['target']

val_data_for_regressor = val_with_weights[training_features_and_target].dropna()

x_val = val_data_for_regressor[training_features]
y_val = val_data_for_regressor['target']

xgb_r = xgb.XGBRegressor(n_estimators=100, objective = 'reg:absoluteerror', eval_metric='mae')

xgb_r.fit(x_train, y_train)

print(1/y_val.shape[0] * np.sum(abs(xgb_r.predict(x_val)-y_val)))
# Out:
# 5.881909168843

# %%
quantitative_features_and_new_target = quantitative_features.copy()
quantitative_features_and_new_target.append('new_target')

# %%
training_data_for_regressor = train_with_weights[quantitative_features_and_new_target].dropna()

x_train = training_data_for_regressor[quantitative_features]
y_train = training_data_for_regressor['new_target']

val_data_for_regressor = val_with_weights[quantitative_features_and_new_target].dropna()

x_val = val_data_for_regressor[quantitative_features]
y_val = val_data_for_regressor['new_target']

xgb_r = xgb.XGBRegressor(n_estimators=100, objective = 'reg:absoluteerror', eval_metric='mae')

xgb_r.fit(x_train, y_train)

print(xgb_r.score(x_val, y_val))

print(1/y_val.shape[0] * np.sum(np.abs(y_val - xgb_r.predict(x_val))))
# Out:
# 0.7806515333712675
# 0.0006935665346231938

# %%
training_data_for_regressor = train_with_weights[quantitative_features_and_new_target].dropna()

x_train = training_data_for_regressor[quantitative_features]
y_train = training_data_for_regressor['new_target']

val_data_for_regressor = val_with_weights[quantitative_features_and_new_target].dropna()

x_val = val_data_for_regressor[quantitative_features]
y_val = val_data_for_regressor['new_target']

xgb_r = xgb.XGBRegressor(n_estimators=100, objective = 'reg:absoluteerror', eval_metric='mae')

xgb_r.fit(x_train, y_train)

print(xgb_r.score(x_val, y_val))

print(1/y_val.shape[0] * np.sum(np.abs(y_val - xgb_r.predict(x_val))))

# %%
training_data_for_regressor
# Out:
#          seconds_in_bucket   imbalance  reference_price  matched_size  \
# 0                        0  3180602.69         0.999812   13380276.64
# 1                       10  1299772.70         1.000026   15261106.63
# 2                       20  1299772.70         0.999919   15261106.63
# 3                       30  1299772.70         1.000133   15261106.63
# 4                       40  1218204.43         1.000455   15342674.90
# ...                    ...         ...              ...           ...
# 4346804                440  3524424.41         1.000982   25472984.20
# 4346805                450  3524424.41         1.000982   25472984.20
# 4346806                460  1070524.12         1.001209   27926884.49
# 4346807                470        0.00         1.001152   28997408.62
# 4346808                480        0.00         1.001209   28997408.62
#
#          bid_price  bid_size  ask_price   ask_size       wap  new_target
# 0         0.999812  60651.50   1.000026    8493.03  1.000000    1.000517
# 1         0.999812  13996.50   1.000026   23519.16  0.999892    1.000421
# 2         0.999812   4665.50   0.999919   12131.60  0.999842    1.000148
# 3         1.000026  55998.00   1.000133   46203.30  1.000085    1.000426
# 4         1.000241  14655.95   1.000455   26610.45  1.000317    1.000261
# ...            ...       ...        ...        ...       ...         ...
# 4346804   1.000584  52289.82   1.001038   34171.16  1.000859    1.001274
# 4346805   1.000584  57043.44   1.001038   69575.30  1.000789    1.002027
# 4346806   1.000982  53015.13   1.001323   53385.57  1.001152    1.002022
# 4346807   1.000811  75723.00   1.001323  117518.73  1.001012    1.001855
# 4346808   1.000811  86465.10   1.001323  106242.57  1.001041    1.001716
#
# [3872617 rows x 10 columns]

# %%
plt.scatter(y_val, xgb_r.predict(x_val), alpha=0.1)
plt.plot([-1,2],[-1,2], color='black', ls='--')
plt.xlim(0.97, 1.09)
plt.ylim(0.98,1.02)
plt.xlabel('Real Weighted Average Price 60 seconds later')
plt.ylabel('Predicted Weighted Average Price 60 seconds later')
# Out:
# Text(0, 0.5, 'Predicted Weighted Average Price 60 seconds later')

# %%
training_data_for_regressor = train_one_hot_stocks[training_features_and_one_hot_and_new_target].dropna()

x_train = training_data_for_regressor[training_features]
y_train = training_data_for_regressor['new_target']

val_data_for_regressor = val_one_hot_stocks[training_features_and_one_hot_and_new_target].dropna()

x_val = val_data_for_regressor[training_features]
y_val = val_data_for_regressor['new_target']

xgb_r = xgb.XGBRegressor(n_estimators=100, objective = 'reg:absoluteerror', eval_metric='mae')

xgb_r.fit(x_train, y_train)

print(xgb_r.score(x_val, y_val))

print(1/y_val.shape[0] * np.sum(np.abs(y_val - xgb_r.predict(x_val))))
# Out:
# 0.800533778537404
# 0.0006881551863529853

# %%
from tqdm import tqdm

index_df = pd.DataFrame()

for group, df_group in tqdm(train_with_weights.groupby(['date_id', 'seconds_in_bucket'])):

    index_df_second = pd.DataFrame()
    
    for feature in df_group.columns:
        if feature!='seconds_in_bucket' and feature!='date_id':
            index_df_second[feature] = [(df_group[feature]*df_group['weight']/df_group['weight'].sum()).sum()]
    index_df_second['seconds_in_bucket'] = [df_group['seconds_in_bucket'].iloc[0]]
    index_df_second['date_id']           = [df_group['date_id'].iloc[0]]
    
    index_df = pd.concat([index_df, index_df_second])
index_df_for_training = index_df[(index_df['seconds_in_bucket']>=60) & (index_df['seconds_in_bucket']<=480)]
# Out:
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                    | 19218/22000 [03:26<00:28, 98.87it/s]

# %%
index_df_val = pd.DataFrame()

for group, df_group in tqdm(val_with_weights.groupby(['date_id', 'seconds_in_bucket'])):

    index_df_second = pd.DataFrame()
    
    for feature in df_group.columns:
        if feature!='seconds_in_bucket' and feature!='date_id':
            index_df_second[feature] = [(df_group[feature]*df_group['weight']/df_group['weight'].sum()).sum()]
    index_df_second['seconds_in_bucket'] = [df_group['seconds_in_bucket'].iloc[0]]
    index_df_second['date_id']           = [df_group['date_id'].iloc[0]]
    
    index_df_val = pd.concat([index_df_val, index_df_second])
    
index_df_for_val = index_df_val[(index_df_val['seconds_in_bucket']>=60) & (index_df_val['seconds_in_bucket']<=480)]

# %%
index_df_val
# Out:
#       stock_id  imbalance_size  imbalance_buy_sell_flag  reference_price  \
# 0   104.182341    1.898381e+07                 0.203045         0.999883
# 0   104.182341    1.737465e+07                 0.215046         1.000128
# 0   104.182341    1.698346e+07                 0.211042         0.999988
# 0   104.182341    1.693473e+07                 0.201042         1.000034
# 0   104.182341    1.730297e+07                 0.185048         0.999771
# ..         ...             ...                      ...              ...
# 0   104.182341    5.933144e+06                -0.105984         0.998861
# 0   104.182341    6.160855e+06                -0.111961         0.998896
# 0   104.182341    6.173394e+06                -0.096968         0.998824
# 0   104.182341    5.957480e+06                -0.087970         0.998829
# 0   104.182341    5.650613e+06                -0.032955         0.998791
#
#     matched_size  far_price  near_price  bid_price       bid_size  ask_price  \
# 0   5.839232e+07   0.000000    0.000000   0.999654   34409.940488   1.000314
# 0   6.049426e+07   0.000000    0.000000   0.999876   46203.343951   1.000351
# 0   6.093939e+07   0.000000    0.000000   0.999749   42314.892838   1.000187
# 0   6.099839e+07   0.000000    0.000000   0.999819   37890.126880   1.000244
# 0   6.098977e+07   0.000000    0.000000   0.999557   38784.619192   0.999945
# ..           ...        ...         ...        ...            ...        ...
# 0   1.738187e+08   0.998832    0.998781   0.998738  108400.892522   0.998992
# 0   1.737329e+08   0.998835    0.998806   0.998774  137875.524898   0.999016
# 0   1.737816e+08   0.998801    0.998757   0.998703  112064.081727   0.998951
# 0   1.741060e+08   0.998803    0.998749   0.998702  120027.422083   0.998944
# 0   1.742885e+08   0.998793    0.998735   0.998654  153795.849550   0.998899
#
#     ...  shifted by 6 ask_size  shifted by 1 wap  shifted by 2 wap  \
# 0   ...               0.000000          0.000000          0.000000
# 0   ...               0.000000          1.000000          0.000000
# 0   ...               0.000000          1.000137          1.000000
# 0   ...               0.000000          0.999966          1.000137
# 0   ...               0.000000          1.000017          0.999966
# ..  ...                    ...               ...               ...
# 0   ...          106094.211931          0.998782          0.998868
# 0   ...           95090.323818          0.998855          0.998782
# 0   ...          112905.358972          0.998894          0.998855
# 0   ...          138849.550887          0.998812          0.998894
# 0   ...          113185.667895          0.998808          0.998812
#
#     shifted by 3 wap  shifted by 4 wap  shifted by 5 wap  shifted by 6 wap  \
# 0           0.000000          0.000000          0.000000          0.000000
# 0           0.000000          0.000000          0.000000          0.000000
# 0           0.000000          0.000000          0.000000          0.000000
# 0           1.000000          0.000000          0.000000          0.000000
# 0           1.000137          1.000000          0.000000          0.000000
# ..               ...               ...               ...               ...
# 0           0.998825          0.998888          0.998803          0.998912
# 0           0.998868          0.998825          0.998888          0.998803
# 0           0.998782          0.998868          0.998825          0.998888
# 0           0.998855          0.998782          0.998868          0.998825
# 0           0.998894          0.998855          0.998782          0.998868
#
#     new_target  seconds_in_bucket  date_id
# 0     0.999388                  0      400
# 0     0.999195                 10      400
# 0     0.999408                 20      400
# 0     0.999344                 30      400
# 0     0.999316                 40      400
# ..         ...                ...      ...
# 0     0.000000                500      480
# 0     0.000000                510      480
# 0     0.000000                520      480
# 0     0.000000                530      480
# 0     0.000000                540      480
#
# [4455 rows x 73 columns]

# %%
index_df_for_training = index_df[(index_df['seconds_in_bucket']>=60) & (index_df['seconds_in_bucket']<=480)]

# %%
quantitative_features_and_target = quantitative_features.copy()
quantitative_features_and_target.append('target')

# %%
final_validation_data = val_with_weights[quantitative_features_and_target+['date_id']]

# %%
all_relevant_features = quantitative_features_and_new_target + ['date_id']
index_df_val_relevant = index_df_val[all_relevant_features]

# %%
final_validation_data.dtypes
# Out:
# seconds_in_bucket      int64
# imbalance            float64
# reference_price      float64
# matched_size         float64
# bid_price            float64
# bid_size             float64
# ask_price            float64
# ask_size             float64
# wap                  float64
# target               float64
# date_id                int64
# dtype: object

# %%
index_df_val_relevant = index_df_val_relevant.rename(columns = {feature: 'index '+feature for feature in quantitative_features_and_new_target})
index_df_val_relevant = index_df_val_relevant.rename(columns = {'index seconds_in_bucket':'seconds_in_bucket'})

# %%
index_df_val_relevant
# Out:
#     seconds_in_bucket  index imbalance  index reference_price  \
# 0                   0     1.045860e+07               0.999883
# 0                  10     8.092764e+06               1.000128
# 0                  20     8.083373e+06               0.999988
# 0                  29     7.987118e+06               1.000034
# 0                  40     7.951866e+06               0.999771
# ..                ...              ...                    ...
# 0                 499    -1.724128e+06               0.998861
# 0                 509    -1.863924e+06               0.998896
# 0                 520    -1.331615e+06               0.998824
# 0                 530    -1.461910e+06               0.998829
# 0                 540    -1.106609e+06               0.998791
#
#     index matched_size  index bid_price  index bid_size  index ask_price  \
# 0         5.839232e+07         0.999654    34409.940488         1.000314
# 0         6.049426e+07         0.999876    46203.343951         1.000351
# 0         6.093939e+07         0.999749    42314.892838         1.000187
# 0         6.099839e+07         0.999819    37890.126880         1.000244
# 0         6.098977e+07         0.999557    38784.619192         0.999945
# ..                 ...              ...             ...              ...
# 0         1.738187e+08         0.998738   108400.892522         0.998992
# 0         1.737329e+08         0.998774   137875.524898         0.999016
# 0         1.737816e+08         0.998703   112064.081727         0.998951
# 0         1.741060e+08         0.998702   120027.422083         0.998944
# 0         1.742885e+08         0.998654   153795.849550         0.998899
#
#     index ask_size  index wap  index new_target  date_id
# 0     35516.432117   1.000000          0.999388      400
# 0     42534.000055   1.000137          0.999195      400
# 0     34455.585384   0.999966          0.999408      400
# 0     41326.188434   1.000017          0.999344      400
# 0     38860.657205   0.999747          0.999316      400
# ..             ...        ...               ...      ...
# 0    138423.040159   0.998855          0.000000      479
# 0    249450.053905   0.998894          0.000000      479
# 0    156420.575902   0.998812          0.000000      479
# 0    255218.023642   0.998808          0.000000      479
# 0    263309.210901   0.998756          0.000000      479
#
# [4455 rows x 11 columns]

# %%
final_validation_data.shape
# Out:
# (890945, 11)

# %%
pd.merge(final_validation_data, index_df_val_relevant, on = ['seconds_in_bucket', 'date_id'])
# Out:
#         seconds_in_bucket    imbalance  reference_price  matched_size  \
# 0                       0  13964576.49         0.999454  1.002071e+07
# 1                       0   2003321.99         0.998651  1.539364e+06
# 2                       0  -1918830.43         1.000470  5.088262e+06
# 3                       0   6350001.93         1.000143  3.258793e+07
# 4                       0   5551852.14         0.999428  7.007913e+06
# ...                   ...          ...              ...           ...
# 730940                540    815054.65         0.999206  4.328851e+07
# 730941                540    541901.49         0.999714  9.180781e+06
# 730942                540   -294082.94         1.000434  2.186296e+07
# 730943                540  -9540823.79         0.996770  1.558377e+08
# 730944                540    311577.88         1.003405  4.098186e+07
#
#         bid_price    bid_size  ask_price   ask_size       wap     target  \
# 0        0.999648    10312.00   1.000521   15275.08  1.000000   0.050068
# 1        0.998065    25527.00   1.002580   34190.00  1.000000 -10.010004
# 2        0.999974     3771.45   1.001236  179925.30  1.000000   7.070303
# 3        0.999964     9777.00   1.000731  196081.38  1.000000   3.780127
# 4        0.999255    26022.00   1.000119    4167.12  1.000000   1.590252
# ...           ...         ...        ...        ...       ...        ...
# 730940   0.999087   347029.41   0.999206  201285.80  0.999162   1.599789
# 730941   0.999464   339588.62   0.999714   86991.97  0.999663  -8.440018
# 730942   1.000434   152726.40   1.000622   84439.68  1.000555   5.149841
# 730943   0.996770  1177519.48   0.997010  872013.89  0.996908  -0.249743
# 730944   1.003088   236698.84   1.003405  212624.70  1.003255  -7.609725
#
#         date_id  index imbalance  index reference_price  index matched_size  \
# 0           400     1.045860e+07               0.999883        5.839232e+07
# 1           400     1.045860e+07               0.999883        5.839232e+07
# 2           400     1.045860e+07               0.999883        5.839232e+07
# 3           400     1.045860e+07               0.999883        5.839232e+07
# 4           400     1.045860e+07               0.999883        5.839232e+07
# ...         ...              ...                    ...                 ...
# 730940      479    -1.106609e+06               0.998791        1.742885e+08
# 730941      479    -1.106609e+06               0.998791        1.742885e+08
# 730942      479    -1.106609e+06               0.998791        1.742885e+08
# 730943      479    -1.106609e+06               0.998791        1.742885e+08
# 730944      479    -1.106609e+06               0.998791        1.742885e+08
#
#         index bid_price  index bid_size  index ask_price  index ask_size  \
# 0              0.999654    34409.940488         1.000314    35516.432117
# 1              0.999654    34409.940488         1.000314    35516.432117
# 2              0.999654    34409.940488         1.000314    35516.432117
# 3              0.999654    34409.940488         1.000314    35516.432117
# 4              0.999654    34409.940488         1.000314    35516.432117
# ...                 ...             ...              ...             ...
# 730940         0.998654   153795.849550         0.998899   263309.210901
# 730941         0.998654   153795.849550         0.998899   263309.210901
# 730942         0.998654   153795.849550         0.998899   263309.210901
# 730943         0.998654   153795.849550         0.998899   263309.210901
# 730944         0.998654   153795.849550         0.998899   263309.210901
#
#         index wap  index new_target
# 0        1.000000          0.999388
# 1        1.000000          0.999388
# 2        1.000000          0.999388
# 3        1.000000          0.999388
# 4        1.000000          0.999388
# ...           ...               ...
# 730940   0.998756          0.000000
# 730941   0.998756          0.000000
# 730942   0.998756          0.000000
# 730943   0.998756          0.000000
# 730944   0.998756          0.000000
#
# [730945 rows x 20 columns]

# %%
index_df[quantitative_features_and_new_target]
# Out:
#     seconds_in_bucket     imbalance  reference_price  matched_size  bid_price  \
# 0                   0  1.348514e+07         0.999939  5.294116e+07   0.999727
# 0                  10  1.341517e+07         1.000350  5.420386e+07   1.000112
# 0                  20  1.329667e+07         1.000515  5.427159e+07   1.000290
# 0                  30  1.317921e+07         1.000517  5.441085e+07   1.000331
# 0                  40  1.236662e+07         1.000626  5.501538e+07   1.000443
# ..                ...           ...              ...           ...        ...
# 0                 500  1.595514e+05         0.999345  1.352202e+08   0.999215
# 0                 510  1.666657e+05         0.999380  1.350302e+08   0.999250
# 0                 520  5.220817e+05         0.999351  1.354202e+08   0.999212
# 0                 530  1.645040e+06         0.999291  1.346376e+08   0.999158
# 0                 540  1.242014e+05         0.999330  1.349394e+08   0.999195
#
#          bid_size  ask_price       ask_size       wap  new_target
# 0    35750.071040   1.000329   44181.391971  1.000000    1.000815
# 0    48821.248931   1.000584   52181.591061  1.000356    1.000843
# 0    44267.150028   1.000698   50297.393531  1.000525    1.000409
# 0    39184.270913   1.000729   46431.691797  1.000547    1.000345
# 0    51645.363536   1.000823   41465.959797  1.000635    1.000264
# ..            ...        ...            ...       ...         ...
# 0    91883.409005   0.999496  102239.520568  0.999354    0.000000
# 0   178395.066327   0.999531  117777.295892  0.999389    0.000000
# 0   121320.702802   0.999488  131489.716798  0.999361    0.000000
# 0   125667.688043   0.999433  147192.654833  0.999289    0.000000
# 0   141556.446053   0.999466  158000.711586  0.999326    0.000000
#
# [22000 rows x 10 columns]

# %%
training_data_for_regressor = index_df[quantitative_features_and_new_target].dropna()

x_train = training_data_for_regressor[quantitative_features]
y_train = training_data_for_regressor['new_target']

val_data_for_regressor = index_df_val[quantitative_features_and_new_target].dropna()

x_val = val_data_for_regressor[quantitative_features]
y_val = val_data_for_regressor['new_target']

xgb_r_index = xgb.XGBRegressor(n_estimators=100, objective = 'reg:absoluteerror', eval_metric='mae')

xgb_r_index.fit(x_train, y_train)

print(xgb_r_index.score(x_val, y_val))

print(1/y_val.shape[0] * np.sum(np.abs(y_val - xgb_r_index.predict(x_val))))
# Out:
# 0.8236552366669762
# 0.00037323266480889037

# %%
from sklearn.linear_model import LinearRegression

training_data_for_regressor = index_df_for_training[quantitative_features_and_new_target].dropna()

index_x_train = training_data_for_regressor[quantitative_features]
index_y_train = training_data_for_regressor['new_target']

val_data_for_regressor = index_df_for_val[quantitative_features_and_new_target].dropna()

index_x_val = val_data_for_regressor[quantitative_features]
index_y_val = val_data_for_regressor['new_target']

index_lr = LinearRegression()
index_lr.fit(index_x_train, index_y_train)
print(index_lr.score(index_x_val, index_y_val))
print(1/index_y_val.shape[0] * np.sum(np.abs(index_y_val - index_lr.predict(index_x_val))))

# %%
training_data_for_regressor = train_with_weights[quantitative_features_and_new_target].dropna()

x_train = training_data_for_regressor[quantitative_features]
y_train = training_data_for_regressor['new_target']

val_data_for_regressor = val_with_weights[quantitative_features_and_new_target].dropna()

x_val = val_data_for_regressor[quantitative_features]
y_val = val_data_for_regressor['new_target']

lr = LinearRegression()
lr.fit(x_train, y_train)
print(lr.score(x_val, y_val))
print(1/y_val.shape[0] * np.sum(np.abs(y_val - lr.predict(x_val))))
# Out:
# 0.8153236554975143
# 0.0006869893323056459

# %%
plt.scatter(y_val, xgb_r.predict(x_val), alpha=0.1)
plt.scatter(y_val, lr.predict(x_val), alpha=0.1)

plt.plot([-1,2],[-1,2], color='black', ls='--')
plt.xlim(0.94, 1.12)
plt.ylim(0.95,1.05)
plt.xlabel('Real Weighted Average Price 60 seconds later')
plt.ylabel('Predicted Weighted Average Price 60 seconds later')
# Out:
# Text(0, 0.5, 'Predicted Weighted Average Price 60 seconds later')

# %%
plt.hist(y_val - lr.predict(x_val), bins=100)
plt.yscale('log')

# %%
predictions = (lr.predict(val_with_weights[quantitative_features])/val_with_weights['wap']
 - index_lr.predict(index_df_for_val[quantitative_features])/index_df_for_val['wap'])*10000

# %%
pd.merge(val_with_weights, index_dx_for_val[
# Out:
#       stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0   104.182341    400.0               70.0    1.714886e+07
# 0   104.182341    400.0               80.0    1.709817e+07
# 0   104.182341    400.0               90.0    1.709973e+07
# 0   104.182341    400.0              100.0    1.708615e+07
# 0   104.182341    400.0              110.0    1.713580e+07
# ..         ...      ...                ...             ...
# 0   104.182341    480.0              440.0    1.199265e+07
# 0   104.182341    480.0              450.0    1.077738e+07
# 0   104.182341    480.0              460.0    8.932942e+06
# 0   104.182341    480.0              470.0    7.563557e+06
# 0   104.182341    480.0              480.0    6.731070e+06
#
#     imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                  0.113039         0.999210  6.271918e+07   0.000000
# 0                  0.110043         0.999401  6.276949e+07   0.000000
# 0                  0.111034         0.999335  6.275656e+07   0.000000
# 0                  0.116042         0.999333  6.279532e+07   0.000000
# 0                  0.112042         0.999409  6.286016e+07   0.000000
# ..                      ...              ...           ...        ...
# 0                 -0.233019         0.998916  1.667468e+08   0.973079
# 0                 -0.230015         0.998807  1.679685e+08   0.973521
# 0                 -0.264993         0.998908  1.701670e+08   0.988677
# 0                 -0.146989         0.998839  1.718037e+08   0.998775
# 0                 -0.117986         0.998878  1.730853e+08   0.998837
#
#     near_price  bid_price  ...  shifted by 4 ask_size  shifted by 5 ask_size  \
# 0     0.000000   0.999047  ...           41326.188434           34455.585384
# 0     0.000000   0.999217  ...           38860.657205           41326.188434
# 0     0.000000   0.999160  ...           42792.717874           38860.657205
# 0     0.000000   0.999155  ...           38084.622946           42792.717874
# 0     0.000000   0.999249  ...           44427.918606           38084.622946
# ..         ...        ...  ...                    ...                    ...
# 0     0.995126   0.998788  ...           88210.581129           77639.602024
# 0     0.995503   0.998671  ...           90061.385973           88210.581129
# 0     0.998225   0.998765  ...           84146.626647           90061.385973
# 0     0.998707   0.998705  ...           97635.426101           84146.626647
# 0     0.998811   0.998745  ...          106094.211931           97635.426101
#
#     shifted by 6 ask_size  shifted by 1 wap  shifted by 2 wap  \
# 0            42534.000055          0.999388          0.999567
# 0            34455.585384          0.999195          0.999388
# 0            41326.188434          0.999408          0.999195
# 0            38860.657205          0.999344          0.999408
# 0            42792.717874          0.999316          0.999344
# ..                    ...               ...               ...
# 0            72264.388002          0.998960          0.998969
# 0            77639.602024          0.998912          0.998960
# 0            88210.581129          0.998803          0.998912
# 0            90061.385973          0.998888          0.998803
# 0            84146.626647          0.998825          0.998888
#
#     shifted by 3 wap  shifted by 4 wap  shifted by 5 wap  shifted by 6 wap  \
# 0           0.999747          1.000017          0.999966          1.000137
# 0           0.999567          0.999747          1.000017          0.999966
# 0           0.999388          0.999567          0.999747          1.000017
# 0           0.999195          0.999388          0.999567          0.999747
# 0           0.999408          0.999195          0.999388          0.999567
# ..               ...               ...               ...               ...
# 0           0.999046          0.998955          0.998926          0.998958
# 0           0.998969          0.999046          0.998955          0.998926
# 0           0.998960          0.998969          0.999046          0.998955
# 0           0.998912          0.998960          0.998969          0.999046
# 0           0.998803          0.998912          0.998960          0.998969
#
#     new_target
# 0     0.999412
# 0     0.999600
# 0     0.999786
# 0     0.999636
# 0     0.999727
# ..         ...
# 0     0.998855
# 0     0.998894
# 0     0.998812
# 0     0.998808
# 0     0.998756
#
# [3402 rows x 73 columns]

# %%
lr.predict(val_with_weights[quantitative_features])/val_with_weights['wap']
# Out:
# 0         0.999975
# 1         1.000063
# 2         1.000086
# 3         1.000066
# 4         0.999991
#             ...
# 890940    0.999993
# 890941    0.999950
# 890942    0.999962
# 890943    0.999958
# 890944    0.999970
# Name: wap, Length: 890945, dtype: float64

# %%
predictions.shape
# Out:
# (894346,)

# %%
val_with_weights.shape
# Out:
# (890945, 73)

# %%
plt.scatter(val_with_weights['target'],predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 plt.scatter(val_with_weights['target'],predictions)
#
# File ~/miniforge3/envs/optiver/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/miniforge3/envs/optiver/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/optiver/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
val_with_weights[quantitative_features_and_new_target].dropna()
